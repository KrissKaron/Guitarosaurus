# %%
import requests as rq
from bs4 import BeautifulSoup as bs
import lxml
import html5lib
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
 
# BS4
#source = rq.get('https://www.thomann.de/ro/chitare_electrice.html').text
#soup = bs(source,'lxml')
 
# SELENIUM
options = Options()
options.add_experimental_option("detach",True)
browser = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=options)
browser.get('https://www.thomann.de/ro/chitare_electrice.html')
# Out:
# /tmp/ipykernel_19256/662231497.py:18: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=options)
# /tmp/ipykernel_19256/662231497.py:18: DeprecationWarning: use options instead of chrome_options
#   browser = webdriver.Chrome(ChromeDriverManager().install(),chrome_options=options)

# %%
def cookiesPopup():
    #Wait for the Popup to emerge
    browser.implicitly_wait(10)
    #Find the "Accept cookies" button and click it
    browser.find_element(By.XPATH,'/html/body/div[2]/div/div/div/div[2]/button[1]').click()
 
def return_main_categs():
    categories = browser.find_elements(By.CSS_SELECTOR,'.fx-category-grid')
    print(len(categories))
    categ_names = []
    for i in categories:
        categ_names.append(i.text)
    categ_names = categ_names[0].split('\n')
    return categ_names
 
def show_categories(categ=return_main_categs()):
    categ_no = []
    categ_title = []
    for i,val in enumerate(categ):
        print(i,'. ',val)
        categ_no.append(i)
        categ_title.append(val)
    return categ_no,categ_title
 
def select_category(categ_title = show_categories()[1]):
    categ_input = int(input('\nSelect the number of the category you want to see: '))
    print('Showing the '+categ_title[categ_input]+' subcategory.\n')
    browser.implicitly_wait(5)
    browser.find_element(By.LINK_TEXT,categ_title[categ_input]).click()

def pick_all_per_page():
    items = browser.find_elements(By.CLASS_NAME,'fx-product-list-entry')
    # print(items,'\n',len(items),'\n')
    item_val = []
    item_index = []
    for i,val in enumerate(items):
        # print("INDEX ITEM: ",i,"\nVALOARE ITEM: \n",val.text,'\n')
        item_val.append(val.text)
        item_index.append(i)
    return item_index,item_val,items

def open_every_item_in_new_tab(vals):
    browser.implicitly_wait(5)
    just_item_titles = []
    for i in vals:
        just_item_titles.append(i.split('\n'))
    print(just_item_titles,'\n',len(just_item_titles),'\n\n')

    span_brandName = browser.find_element(By.CLASS_NAME,'title__manufacturer').text
    span_model = browser.find_element(By.CLASS_NAME,'title__name').text

    for index,i in enumerate(just_item_titles):
        print(index,'\nMANUFACTURER: ',span_brandName,'\nMODEL: ',span_model,'\n')
        browser.find_elements(By.PARTIAL_LINK_TEXT,span_model)
        item_links = [] 
        item_links.append(browser.find_elements(By.PARTIAL_LINK_TEXT,span_model))
       
        link = browser.find_elements(By.PARTIAL_LINK_TEXT,span_model)[index].get_attribute('href')
        links = []
        links.append(link)
        print(links)
       
        #print('\n',len(links))
        for x in range(0, len(links)):
            browser.execute_script("window.open();")
            browser.switch_to.window(browser.window_handles[x])
            browser.get(links[x-1])
    return span_brandName, span_model, just_item_titles, item_links, link, links
# Out:
# 1
# 0 .  Seturi de Chitară
# 1 .  Modele ST
# 2 .  Modele-T
# 3 .  Modele Single Cut
# 4 .  Modele Double Cut
# 5 .  Chitare Semiacustice
# 6 .  Chitare Heavy
# 7 .  Chitare pt. Stângaci
# 8 .  Premium Class
# 9 .  Chitare Jazz
# 10 .  Chitare cu 7-Corzi
# 11 .  Chitare cu 8 corzi
# 12 .  Chitare fanned-fret
# 13 .  Chitare Headless
# 14 .  Chitare cu 12 corzi
# 15 .  Chitare Bariton
# 16 .  Chitare cu Scală Mică
# 17 .  Chitare MIDI-, Digitale şi cu Simulatoare
# 18 .  Chitare Electrice cu Doze-Piezo
# 19 .  Modele de Chitară Alternative
# 20 .  Chitare cu Semnătură
# 21 .  GuitarLab: Găsiți chitara la care visați

# %%
if __name__ == '__main__':
    cookiesPopup()
    select_category()
    _,vals,_ = pick_all_per_page()
    span_brandName, span_model, just_item_titles, item_links, link, links = open_every_item_in_new_tab(vals)
# Out:
# Showing the Modele Single Cut subcategory.
#
# [['Harley Benton SC-1000 SBK Progressive Line', '434', 'Progressive Line', 'Archtop body', 'Body: Mahogany (Entandrophragma Cylindricum)', 'Disponibil în timp scurt (de obicei 2-5 zile)', '969 lei'], ['Harley Benton Electric Guitar Kit Single Cut', '1036', 'Complete DIY (do it yourself) kit', 'Neck attachment: Bolt-on', 'Body: Rengas (wood colour may vary)', 'în stoc', '479 lei', 'TOP SELLER'], ['Harley Benton SC-450 P90 GT Classic Series', '423', 'Classic Series', 'Body: Poplar', 'Arched top', 'Disponibil în timp scurt (de obicei 2-5 zile)', '725 lei'], ['Gibson Les Paul Custom EB GH', '94', 'Body: Mahogany (Swietenia macrophylla)', 'Arched top: Maple', 'Neck: Mahogany', 'în stoc', '21.790 lei'], ['Harley Benton SC-450Plus LD Vintage Series', '549', 'Vintage series', 'Body: Mahogany (Entandrophragma cylindricum, Indonesian mahogany/sapele)', 'Arched top made of AAA flamed maple', 'în stoc', '869 lei'], ['Harley Benton SC-450Plus HB Vintage Series', '231', 'Vintage Series', 'Body: mahogany', 'Arched top: AAA flamed maple', 'Disponibil în timp scurt (de obicei 2-5 zile)', '869 lei'], ['Harley Benton SC-500 BK Vintage Series', '260', 'Vintage Series', 'Body: Basswood', 'Arched top', 'Disponibil în timp scurt (de obicei 2-5 zile)', '822 lei'], ['Harley Benton SC-450Plus CB Vintage Series', '205', 'Vintage Series', 'Body: Mahogany (Entandrophragma cylindricum, Indonesian mahagony/ sapele)', 'Arched top: AAA flamed maple', 'Disponibil în timp scurt (de obicei 2-5 zile)', '869 lei'], ['Harley Benton SC-Custom II Vintage Black', '45', 'Custom Line Series', 'Body: Mahogany', 'Neck: Mahogany', 'Disponibil în timp scurt (de obicei 2-5 zile)', '1.299 lei'], ['Epiphone 1959 LP Standard Outfit ADB', '30', 'Limited edition', 'Top: Flamed maple', 'Body: Mahogany', 'în stoc', '3.690 lei'], ['Harley Benton SC-550 II PAF', '62', 'Deluxe Series', 'Chambered mahogany body (Swietenia Meliaceae)', 'Curved AAA maple top', 'Disponibil în timp scurt (de obicei 2-5 zile)', '1.444 lei'], ['Epiphone Les Paul Player Pack VS', '90', 'Electric guitar: Epiphone Special II LTD', 'Guitar amplifier: Epiphone Electar-10', 'Gig bag', 'în stoc', '1.035 lei'], ['Harley Benton SC-400 SBK Vintage Series', '223', 'Classic series', 'Body: Basswood', 'Arched top', 'Disponibil în timp scurt (de obicei 2-5 zile)', '629 lei'], ['Harley Benton SC-500 WH Vintage Series', '139', 'Vintage Series', 'Body: Basswood', 'Arched top', 'Disponibil în timp scurt (de obicei 2-5 zile)', '822 lei'], ['Harley Benton SC-1000 WH Progressive Line', '148', 'Progressive Line', 'Body: Mahogany body with arched top (Entandrophragma cylindricum, Indonesian mahogany/Sapele)', 'Neck: Okoume', 'Disponibil în timp scurt (de obicei 2-5 zile)', '969 lei'], ['Harley Benton SC-450 BK Classic Series', '121', 'Classic series', 'Body: Basswood', 'Arched top', 'în stoc', '677 lei'], ['Gibson Les Paul Classic HCS', '19', 'Body: Mahogany', 'Top: Maple', '"9-hole Weight Relief" - weight-reduced body', 'în stoc', '9.699 lei'], ['Harley Benton SC-400 SGT Classic Series', '166', 'Classic Series', 'Body: Basswood', 'Arched top', 'în stoc', '725 lei'], ['Harley Benton SC-Custom II FR Vintage Black', '59', 'Series: Custom Line', 'Body: Mahogany', 'Neck: Mahogany', 'Disponibil în timp scurt (de obicei 2-5 zile)', '1.839 lei'], ['Harley Benton SC-550 II PAF Bundle', 'Electric guitar', 'Deluxe Series', 'Chambered mahogany body (Swietenia Meliaceae)', 'Disponibil în timp scurt (de obicei 2-5 zile)', '1.590 lei'], ['Gibson Les Paul Slash Standard NB', '3', 'Slash signature model', 'Body: Mahogany (Swietenia macrophylla - Origin: India/ Indonesia)', 'Top: AAA flamed maple', 'în stoc', '13.090 lei'], ['Harley Benton SC-Custom II Ocean Flame', '38', 'Custom Line Series', 'Body: Mahogany', 'Top: AAAA flamed maple veneer', 'Disponibil în timp scurt (de obicei 2-5 zile)', '1.259 lei'], ['Gibson Les Paul Standard 60s IT', '53', 'Body: Mahogany (Swietenia macrophylla)', 'Cream-coloured body binding', 'Top: AA flamed maple', 'în s ...
#  25
#
#
# 0
# MANUFACTURER:  Harley Benton
# MODEL:  SC-1000 SBK Progressive Line
#
# ['https://www.thomann.de/ro/harley_benton_l1000_vb_progressive_line.htm?listPosition=0&type=category']
# 1
# MANUFACTURER:  Harley Benton
# MODEL:  SC-1000 SBK Progressive Line
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 5
#       3 select_category()
#       4 _,vals,_ = pick_all_per_page()
# ----> 5 span_brandName, span_model, just_item_titles, item_links, link, links = open_every_item_in_new_tab(vals)
#
# Cell In[7], line 58, in open_every_item_in_new_tab(vals)
#      55 item_links = []
#      56 item_links.append(browser.find_elements(By.PARTIAL_LINK_TEXT,span_model))
# ---> 58 link = browser.find_elements(By.PARTIAL_LINK_TEXT,span_model)[index].get_attribute('href')
#      59 links = []
#      60 links.append(link)
#
# IndexError: list index out of range
